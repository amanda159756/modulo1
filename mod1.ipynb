# %% [markdown]
# Esse arquivo está vazio, apenas para teste =)
# Suba em uma pasta no seu computador, de preferência um caminho de pastas igual o da aula e tente refazer os comandos usando os passos do material.
